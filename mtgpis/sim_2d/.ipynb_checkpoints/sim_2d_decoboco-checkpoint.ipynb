# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import sys
sys.path.append("../")

from kernel import InverseMultiquadricKernelPytouch
from mtgp import MultiTaskGaussianProcessImplicitSurfaces

import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
plt.style.use("ggplot")

# %matplotlib inline

# %%
def plot_all(model, x1, y1, x2, y2, rate):
    x   = np.linspace(-10, 70, 200)[:, None] * rate
    y   = np.linspace(-10, 70, 200)[:, None] * rate
    x,y = np.meshgrid(x, y)
    xx  = x.ravel()[:, None]
    yy  = y.ravel()[:, None]
    XX  = np.concatenate([xx, yy], 1)
    XX  = torch.from_numpy(XX).float()

    mm1, ss1 = model.predict(XX, 0)
    mm2, ss2 = model.predict(XX, 1)

    d = np.where(abs(mm2.T[0]) < 0.1)
    e = xx.T[0][d]
    f = yy.T[0][d]

    plt.xlim(-0.1, 0.7)
    plt.ylim(-0.1, 0.7)


    mm1 = mm1.reshape(x.shape)
    mm2 = mm2.reshape(x.shape)

    z = mm2.numpy()

    xyz = plt.pcolormesh(x, y, z, cmap='Greens', shading="gouraud", vmax=z.max(), vmin=z.min())

    x2_ = np.concatenate([np.ones(N1)*12, np.linspace(12, 20, N2//2), np.ones(N2)*20, np.linspace(20, 40, N2), np.ones(N2)*40, np.linspace(40, 48, N2//2), np.ones(N1)*48]) * rate
    y2_ = np.concatenate([np.linspace(15, 47, N1), np.ones(N2//2)*47, np.linspace(47, 20, N2), np.ones(N2)*20, np.linspace(20, 47, N2), np.ones(N2//2)*47, np.linspace(47, 15, N1)]) * rate
    
    plt.plot(x2_, y2_, linewidth=5, c='black')
    
    plt.plot(x1_0, y1_0, linewidth=5, alpha=0.5, c='red')
    plt.plot(x2_0, y2_0, linewidth=5, c='blue')
    plt.scatter(e,f, s=10, c='navy')
    # plt.scatter(e,f)
    #     plt.colorbar(xyz)
    # plt.savefig('mtgpis.png')
    plt.show()

    # %matplotlib notebook
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x1.ravel(), y1.ravel(), np.array(Y1).ravel())
    ax.scatter(x2.ravel(), y2.ravel(), np.array(Y2).ravel())

    surf = ax.plot_surface(x, y, z, cmap='bwr', linewidth=0)
    fig.colorbar(surf)
    # plt.savefig('mtgpis_3d.png')
    plt.show()

# %%
N1 = 10
N2 = 10
rate = 0.01 # data scale

# %%
x1_0 = (np.concatenate([np.ones(N1)*50, np.linspace(50, 10, N1), np.ones(N1)*10]) ) * rate
y1_0 = (np.concatenate([np.linspace(10, 50, N1), np.ones(N1)*50, np.linspace(50, 10, N1)]) ) * rate

x2_0 = np.concatenate([np.ones(N1)*12, np.linspace(12, 20, N2//2), np.ones(N2)*20, np.linspace(20, 40, N2), np.ones(N2)*40, np.linspace(40, 48, N2//2), np.ones(N1)*48]) * rate
y2_0 = np.concatenate([np.linspace(15, 47, N1), np.ones(N2//2)*47, np.linspace(47, 20, N2), np.ones(N2)*20, np.linspace(20, 47, N2), np.ones(N2//2)*47, np.linspace(47, 15, N1)]) * rate
    
plt.plot(x1_0, y1_0, linewidth=10)
plt.plot(x2_0, y2_0, linewidth=10)

plt.xlim(-0.1, 0.7)
plt.ylim(-0.1, 0.7)
plt.show()

# %% [markdown]
# # STEP1

# %%
step = 3

x1_0 = (np.concatenate([np.ones(N1)*50, np.linspace(50, 10, N1), np.ones(N1)*10]) + np.random.randn(N1*step) * 0.2) * rate
x1_1 = (np.concatenate([np.ones(N1)*52, np.linspace(52, 8, N1), np.ones(N1)*8]) + np.random.randn(N1*step) * 0.2) * rate
x1    = np.concatenate([x1_0, x1_1])[:, None]

y1_0 = (np.concatenate([np.linspace(10, 50, N1), np.ones(N1)*50, np.linspace(50, 10, N1)]) + np.random.randn(N1*step) * 0.2) * rate
y1_1 = (np.concatenate([np.linspace(8, 52, N1), np.ones(N1)*52, np.linspace(52, 8, N1)]) + np.random.randn(N1*step) * 0.2) * rate
y1    = np.concatenate([y1_0, y1_1])[:, None]

X1 = np.concatenate([x1,y1],1)
Y1 = np.concatenate([np.zeros(len(x1_0)), np.ones(len(x1_1)) ])[:, None]
T1 = 0

# %%
x2_0 = np.concatenate([np.linspace(12, 20, N2//2)]) 
x2_0 = (x2_0 + np.random.randn(len(x2_0)) * 0.2) * rate  

x2_1 = np.concatenate([np.linspace(12, 22, N2//2)]) 
x2_1 = (x2_1 + np.random.randn(len(x2_1)) * 0.2) * rate
                       
x2    = np.concatenate([x2_0, x2_1])[:, None]


y2_0 = np.concatenate([np.ones(N2//2)*47]) 
y2_0 = (y2_0 + np.random.randn(len(y2_0)) * 0.2) * rate 
    
y2_1 = np.concatenate([np.ones(N2//2)*49]) 
y2_1 = (y2_1 + np.random.randn(len(y2_1)) * 0.2) * rate 
    
y2    = np.concatenate([y2_0, y2_1])[:, None]


X2 = np.concatenate([x2,y2], 1)
Y2 = np.concatenate([np.zeros(len(x2_0)), np.ones(len(x2_1))])[:, None]
T2 = 1
# print(X2.shape)
# print(Y2.shape)

# %%
plt.plot(x1_0, y1_0, linewidth=5)
plt.plot(x2_0, y2_0, linewidth=5)
plt.scatter(x1_0, y1_0)
plt.scatter(x2_0, y2_0)

plt.scatter(x2_1, y2_1)
plt.scatter(x1_1, y1_1)
plt.xlim(-0.1, 0.7)
plt.ylim(-0.1, 0.7)
plt.show()

# %%
X1_t = torch.from_numpy(X1).float()
X2_t = torch.from_numpy(X2).float()
Y1_t = torch.from_numpy(Y1).float()
Y2_t = torch.from_numpy(Y2).float()

kernel = InverseMultiquadricKernelPytouch([0.001])
model  = MultiTaskGaussianProcessImplicitSurfaces([X1_t,X2_t], [Y1_t,Y2_t], [T1,T2], kernel)
print("----- before learning -----")
print(model.task_params_to_psd())
model.learning(max_iter=4000)
print("----- after learning -----")
print(model.task_params_to_psd())
# Out:
# ----- before learning -----
# tensor([[1.0020, 1.0020],
#         [1.0020, 2.0040]])
# task: tensor([[5.7653, 5.8366],
#         [5.8366, 6.3855]])
# sigma: tensor(-3.5048)
# kernel: tensor([0.2216])
# ----- after learning -----
# tensor([[5.7653, 5.8366],
#         [5.8366, 6.3855]])

# %%
colormap = plt.cm.RdBu
sns.heatmap(model.task_params_to_psd().numpy(), linewidths=0.2, 
        square=True, cmap=colormap, linecolor='white')
plt.show()
plot_all(model, x1,y1,x2,y2, rate)

# %%
model.task_kernel_params
# Out:
# tensor([[ 0.8759,  0.8882],
#         [ 0.0010, -0.3704]])

# %% [markdown]
# # STEP2

# %%
x2_0 = np.concatenate([np.linspace(12, 20, N2//2), np.ones(N2)*20]) 
x2_0 = (x2_0 + np.random.randn(len(x2_0)) * 0.2) * rate  

x2_1 = np.concatenate([np.linspace(12, 22, N2//2), np.ones(N2)*22]) 
x2_1 = (x2_1 + np.random.randn(len(x2_1)) * 0.2) * rate
                       
x2    = np.concatenate([x2_0, x2_1])[:, None]


y2_0 = np.concatenate([np.ones(N2//2)*45, np.linspace(45, 20, N2)]) 
y2_0 = (y2_0 + np.random.randn(len(y2_0)) * 0.2) * rate 
    
y2_1 = np.concatenate([np.ones(N2//2)*47, np.linspace(47, 22, N2)]) 
y2_1 = (y2_1 + np.random.randn(len(y2_1)) * 0.2) * rate 
    
y2    = np.concatenate([y2_0, y2_1])[:, None]


X2 = np.concatenate([x2,y2], 1)
Y2 = np.concatenate([np.zeros(len(x2_0)), np.ones(len(x2_1))])[:, None]
T2 = 1
# print(X2.shape)
# print(Y2.shape)

# %%
plt.plot(x1_0, y1_0, linewidth=5)
plt.plot(x2_0, y2_0, linewidth=5)
plt.scatter(x1_0, y1_0)
plt.scatter(x2_0, y2_0)

# plt.scatter(x2_1, y2_1)
# plt.scatter(x1_1, y1_1)
plt.xlim(-0.1, 0.7)
plt.ylim(-0.1, 0.7)
plt.show()

# %%
X1_t = torch.from_numpy(X1).float()
X2_t = torch.from_numpy(X2).float()
Y1_t = torch.from_numpy(Y1).float()
Y2_t = torch.from_numpy(Y2).float()

a=model.task_kernel_params

kernel = InverseMultiquadricKernelPytouch([0.001])
model  = MultiTaskGaussianProcessImplicitSurfaces([X1_t,X2_t], [Y1_t,Y2_t], [T1,T2], kernel, task_kernel_params=model.task_kernel_params)
print("----- before learning -----")
print(model.task_params_to_psd())
model.learning(max_iter=4000)
print("----- after learning -----")
print(model.task_params_to_psd())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-e09f72f4e4ea> in <module>
#       7
#       8 kernel = InverseMultiquadricKernelPytouch([0.001])
# ----> 9 model  = MultiTaskGaussianProcessImplicitSurfaces([X1_t,X2_t], [Y1_t,Y2_t], [T1,T2], kernel, task_kernel_params=model.task_kernel_params)
#      10 print("----- before learning -----")
#      11 print(model.task_params_to_psd())
#
# ~/Desktop/mtgpis/mtgp/mtgpis.py in __init__(self, X, Y, T, kernel, sigma, task_kernel_params)
#      18         # self.task_kernel_params = torch.rand(self.N_task, self.N_task)
#      19
# ---> 20         if task_kernel_params is None:
#      21             self.task_kernel_params = torch.tensor([[10e-4,10e-4],[10e-4,10e-4]])
#      22         else:
#
# TypeError: eq() received an invalid combination of arguments - got (NoneType), but expected one of:
#  * (Tensor other)
#       didn't match because some of the arguments have invalid types: (NoneType)
#  * (Number other)
#       didn't match because some of the arguments have invalid types: (NoneType)

# %%
colormap = plt.cm.RdBu
sns.heatmap(model.task_params_to_psd().numpy(), linewidths=0.2, 
        square=True, cmap=colormap, linecolor='white')
plt.show()
plot_all(model, x1,y1,x2,y2, rate)

# %% [markdown]
# # STEP3

# %%
x2_0 = np.concatenate([np.linspace(12, 20, N2//2), np.ones(N2)*20, np.linspace(20, 40, N2)]) 
x2_0 = (x2_0 + np.random.randn(len(x2_0)) * 0.2) * rate  

x2_1 = np.concatenate([np.linspace(12, 22, N2//2), np.ones(N2)*22, np.linspace(22, 38, N2)]) 
x2_1 = (x2_1 + np.random.randn(len(x2_1)) * 0.2) * rate
                       
x2    = np.concatenate([x2_0, x2_1])[:, None]


y2_0 = np.concatenate([np.ones(N2//2)*45, np.linspace(45, 20, N2), np.ones(N2)*20]) 
y2_0 = (y2_0 + np.random.randn(len(y2_0)) * 0.2) * rate 
    
y2_1 = np.concatenate([np.ones(N2//2)*47, np.linspace(47, 22, N2), np.ones(N2)*22]) 
y2_1 = (y2_1 + np.random.randn(len(y2_1)) * 0.2) * rate 
    
y2    = np.concatenate([y2_0, y2_1])[:, None]


X2 = np.concatenate([x2,y2], 1)
Y2 = np.concatenate([np.zeros(len(x2_0)), np.ones(len(x2_1))])[:, None]
T2 = 1

# %%
plt.plot(x1_0, y1_0, linewidth=5)
plt.plot(x2_0, y2_0, linewidth=5)
# plt.scatter(x1_0, y1_0)
# plt.scatter(x2_0, y2_0)

# plt.scatter(x2_1, y2_1)
# plt.scatter(x1_1, y1_1)
plt.xlim(-0.1, 0.7)
plt.ylim(-0.1, 0.7)
plt.show()

# %%
X1_t = torch.from_numpy(X1).float()
X2_t = torch.from_numpy(X2).float()
Y1_t = torch.from_numpy(Y1).float()
Y2_t = torch.from_numpy(Y2).float()

a=model.task_kernel_params

kernel = InverseMultiquadricKernelPytouch([0.001])
model  = MultiTaskGaussianProcessImplicitSurfaces([X1_t,X2_t], [Y1_t,Y2_t], [T1,T2], kernel)
print("----- before learning -----")
print(model.task_params_to_psd())
model.learning(max_iter=4000)
print("----- after learning -----")
print(model.task_params_to_psd())
# Out:
# ----- before learning -----
# tensor([[1.0020, 1.0020],
#         [1.0020, 2.0040]])
# task: tensor([[2.8430, 0.7917],
#         [0.7917, 4.0815]])
# sigma: tensor(-3.3180)
# kernel: tensor([0.1840])
# ----- after learning -----
# tensor([[2.8430, 0.7917],
#         [0.7917, 4.0815]])

# %%
colormap = plt.cm.RdBu
sns.heatmap(model.task_params_to_psd().numpy(), linewidths=0.2, 
        square=True, cmap=colormap, linecolor='white')
plt.show()
plot_all(model, x1,y1,x2,y2, rate)

# %% [markdown]
# # STEP4

# %%
x2_0 = np.concatenate([np.linspace(12, 20, N2//2), np.ones(N2)*20, np.linspace(20, 40, N2), np.ones(N2)*40, np.linspace(40, 48, N2//2)]) 
x2_0 = (x2_0 + np.random.randn(len(x2_0)) * 0.2) * rate  

x2_1 = np.concatenate([np.linspace(12, 22, N2//2), np.ones(N2)*22, np.linspace(22, 38, N2), np.ones(N2)*38, np.linspace(38, 48, N2//2)]) 
x2_1 = (x2_1 + np.random.randn(len(x2_1)) * 0.2) * rate
                       
x2    = np.concatenate([x2_0, x2_1])[:, None]


y2_0 = np.concatenate([np.ones(N2//2)*45, np.linspace(45, 20, N2), np.ones(N2)*20, np.linspace(20, 45, N2), np.ones(N2//2)*45]) 
y2_0 = (y2_0 + np.random.randn(len(y2_0)) * 0.2) * rate 
    
y2_1 = np.concatenate([np.ones(N2//2)*47, np.linspace(47, 22, N2), np.ones(N2)*22, np.linspace(22, 47, N2), np.ones(N2//2)*47]) 
y2_1 = (y2_1 + np.random.randn(len(y2_1)) * 0.2) * rate 
    
y2    = np.concatenate([y2_0, y2_1])[:, None]


X2 = np.concatenate([x2,y2], 1)
Y2 = np.concatenate([np.zeros(len(x2_0)), np.ones(len(x2_1))])[:, None]
T2 = 1

# %%
plt.plot(x1_0, y1_0, linewidth=5)
plt.plot(x2_0, y2_0, linewidth=5)
# plt.scatter(x1_0, y1_0)
# plt.scatter(x2_0, y2_0)

# plt.scatter(x2_1, y2_1)
# plt.scatter(x1_1, y1_1)
plt.xlim(-0.1, 0.7)
plt.ylim(-0.1, 0.7)
plt.show()

# %%
X1_t = torch.from_numpy(X1).float()
X2_t = torch.from_numpy(X2).float()
Y1_t = torch.from_numpy(Y1).float()
Y2_t = torch.from_numpy(Y2).float()

a=model.task_kernel_params

kernel = InverseMultiquadricKernelPytouch([0.001])
model  = MultiTaskGaussianProcessImplicitSurfaces([X1_t,X2_t], [Y1_t,Y2_t], [T1,T2], kernel)
print("----- before learning -----")
print(model.task_params_to_psd())
model.learning(max_iter=4000)
print("----- after learning -----")
print(model.task_params_to_psd())
# Out:
# ----- before learning -----
# tensor([[1.0020, 1.0020],
#         [1.0020, 2.0040]])
# task: tensor([[1.1856, 0.8748],
#         [0.8748, 2.1467]])
# sigma: tensor(-3.5630)
# kernel: tensor([0.1329])
# ----- after learning -----
# tensor([[1.1856, 0.8748],
#         [0.8748, 2.1467]])

# %%
colormap = plt.cm.RdBu
sns.heatmap(model.task_params_to_psd().numpy(), linewidths=0.2, 
        square=True, cmap=colormap, linecolor='white')
plt.show()
plot_all(model, x1,y1,x2,y2, rate)
